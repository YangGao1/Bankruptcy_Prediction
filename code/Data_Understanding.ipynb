# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('../data/accouting_data/healthy_accouting_stalt.csv')
df2=pd.read_csv('../data/accouting_data/bankruptcy_accouting_stalt.csv')
df2['stalt']=1.0 #label bankruptcy
df1['stalt']=0.0 # label healthy
# Out:
# C:\Users\princ\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2.loc[:,df2.dtypes==object].head()
# Out:
#   indfmt consol popsrc datafmt     tic curcd costat  fic incorp
# 0   INDL      C      D     STD   MTI.3   USD      I  USA     DE
# 1   INDL      C      D     STD     AAL   USD      A  USA     DE
# 2   INDL      C      D     STD  3AWCSA   USD      I  USA     NJ
# 3   INDL      C      D     STD  3ACAJC   USD      I  USA     DE
# 4   INDL      C      D     STD   5710B   USD      I  USA     CA

# %% [markdown]
# ### Observation -Column to delete in bankruptcy
# 1. PLL-Provision for Loan Loss. This value is exclusively for the banks.
# 1. TIE
# 1. UNWCC-working capital change
# 1. USTDNC-short-term debt change
# 1. amgw-Amortization of goodwill
# 1. pvcl-provision of credit loss
# 1. udvp- preferred dividend requirement
# 1. txtubtxr- Impact on effective tax rate
# 1. wdp-writedowns pretax
# 1. teq- stockholder Equity - Total
# 1. dt- total debt

# %%
column_to_delete_b=['pll','tie','unwcc','ustdnc','amgw','pvcl','udvp','txtubtxtr','wdp','teq','dt']
column_to_delete_h=['unwcc','ustdnc','pvcl','udvp','pll','tie','wdp','amgw','txtubtxtr','teq','dt']

# %% [markdown]
# ## Get percent of NaN value

# %% [markdown]
# ### 1.Bankruptcy data

# %%
#NaN percent in bankruptcy data
percent=pd.DataFrame(df2.isnull().sum(axis=0)/df2.shape[0],columns=['column name']).sort_values(by='column name',ascending=False)

# %% [markdown]
# ### 2.Healthy data

# %%
percent2=pd.DataFrame(df1.isnull().sum(axis=0)/df1.shape[0],columns=['column name']).sort_values(by='column name',ascending=False)

# %%
percent2
# Out:
#            column name
# unwcc         0.999399
# ustdnc        0.999255
# pvcl          0.977987
# udvp          0.975477
# pll           0.945923
# tie           0.945394
# wdp           0.941534
# amgw          0.929622
# txtubtxtr     0.906532
# teq           0.663844
# dt            0.560958
# dlrsn         0.474029
# wcap          0.370467
# act           0.366172
# lct           0.359514
# oancf         0.307470
# ivncf         0.307296
# fincf         0.307296
# emp           0.303260
# capx          0.284393
# epsfi         0.283109
# cshpri        0.278420
# oibdp         0.264408
# gdwl          0.262519
# ebit          0.260190
# spcseccd      0.258996
# ceqt          0.251054
# gp            0.246231
# ni            0.244885
# au            0.222041
# intan         0.216661
# incorp        0.205634
# ch            0.185515
# dvt           0.170012
# revt          0.162318
# dvp           0.161973
# lt            0.158200
# at            0.156472
# csho          0.149908
# prcc_f        0.139901
# tic           0.000405
# curcd         0.000233
# fyear         0.000233
# datafmt       0.000000
# popsrc        0.000000
# consol        0.000000
# indfmt        0.000000
# costat        0.000000
# fic           0.000000
# datadate      0.000000
# stalt         0.000000
# gvkey         0.000000
